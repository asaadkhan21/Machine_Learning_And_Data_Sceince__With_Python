# %% [markdown]
# <a href="https://colab.research.google.com/github/asaadkhan21/Machine_Learning_With_Python/blob/main/Lab_12_Aprior.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
dataset=pd.read_csv('Market_Basket_Optimisation.csv')
dataset.head()
# Out:
#            shrimp    almonds     avocado    vegetables mix green grapes  \
# 0         burgers  meatballs        eggs               NaN          NaN
# 1         chutney        NaN         NaN               NaN          NaN
# 2          turkey    avocado         NaN               NaN          NaN
# 3   mineral water       milk  energy bar  whole wheat rice    green tea
# 4  low fat yogurt        NaN         NaN               NaN          NaN
#
#   whole weat flour yams cottage cheese energy drink tomato juice  \
# 0              NaN  NaN            NaN          NaN          NaN
# 1              NaN  NaN            NaN          NaN          NaN
# 2              NaN  NaN            NaN          NaN          NaN
# 3              NaN  NaN            NaN          NaN          NaN
# 4              NaN  NaN            NaN          NaN          NaN
#
#   low fat yogurt green tea honey salad mineral water salmon antioxydant juice  \
# ...

# %%
dataset.isnull().sum()
# Out:
# shrimp                  0
# almonds              1754
# avocado              3112
# vegetables mix       4156
# green grapes         4972
# whole weat flour     5637
# yams                 6132
# cottage cheese       6520
# energy drink         6847
# tomato juice         7106
# low fat yogurt       7245
# green tea            7347
# honey                7414
# salad                7454
# mineral water        7476
# salmon               7493
# antioxydant juice    7497
# frozen smoothie      7497
# spinach              7498
# olive oil            7500
# dtype: int64

# %%
transactions=[]  
for i in range(0, 50):  
    transactions.append([str(dataset.values[i,j])  for j in range(0,20)])

# %%
transactions
# Out:
# [['burgers',
#   'meatballs',
#   'eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chutney',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'avocado',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['mineral water',
#   'milk',
#   'energy bar',
#   'whole wheat rice',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['low fat yogurt',
#   'nan',
#   'nan',
#   'nan',
# ...

# %%
# !pip install apyori
from apyori import apriori
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5973 sha256=c3118e0c6eb4dc96bdd44ae18d425434a52d82b343dec7cb33cb9bd2bf467e86
#   Stored in directory: /root/.cache/pip/wheels/1b/02/6c/a45230be8603bd95c0a51cd2b289aefdd860c1a100eab73661
# Successfully built apyori
# ...

# %%
from apyori import apriori  
rules= apriori(transactions= transactions, min_support=0.003, min_confidence = 0.2, min_lift=3, min_length=2, max_length=2)
results= list(rules)  
results
# Out:
# [RelationRecord(items=frozenset({'avocado', 'body spray'}), support=0.02, ordered_statistics=[OrderedStatistic(items_base=frozenset({'body spray'}), items_add=frozenset({'avocado'}), confidence=0.5, lift=4.166666666666667)]),
#  RelationRecord(items=frozenset({'avocado', 'brownies'}), support=0.02, ordered_statistics=[OrderedStatistic(items_base=frozenset({'brownies'}), items_add=frozenset({'avocado'}), confidence=0.5, lift=4.166666666666667)]),
#  RelationRecord(items=frozenset({'fresh bread', 'avocado'}), support=0.02, ordered_statistics=[OrderedStatistic(items_base=frozenset({'fresh bread'}), items_add=frozenset({'avocado'}), confidence=1.0, lift=8.333333333333334)]),
#  RelationRecord(items=frozenset({'avocado', 'grated cheese'}), support=0.02, ordered_statistics=[OrderedStatistic(items_base=frozenset({'grated cheese'}), items_add=frozenset({'avocado'}), confidence=1.0, lift=8.333333333333334)]),
# ...

# %%
for item in results:  
    pair = item[0]   
    items = [x for x in pair]  
    print("Rule: " + items[0] + " -> " + items[1])  
  
    print("Support: " + str(item[1]))  
    print("Confidence: " + str(item[2][0][2]))  
    print("Lift: " + str(item[2][0][3]))  
    print("=====================================")
# Out:
# Rule: avocado -> body spray
# Support: 0.02
# Confidence: 0.5
# Lift: 4.166666666666667
# ...
# Rule: avocado -> brownies
# Support: 0.02
# Confidence: 0.5
# Lift: 4.166666666666667
# ...
# Rule: fresh bread -> avocado
# Support: 0.02
# Confidence: 1.0
# Lift: 8.333333333333334
# ...
# Rule: avocado -> grated cheese
# Support: 0.02
# Confidence: 1.0
# Lift: 8.333333333333334
# ...
# Rule: avocado -> hot dogs
# Support: 0.02
# Confidence: 0.5
# Lift: 4.166666666666667
# ...
# Rule: avocado -> muffins
# Support: 0.02
# Confidence: 1.0
# Lift: 8.333333333333334
# ...
# Rule: avocado -> pancakes
# Support: 0.02
# Confidence: 0.5
# Lift: 4.166666666666667
# ...
# Rule: avocado -> parmesan cheese
# Support: 0.02
# Confidence: 1.0
# Lift: 8.333333333333334
# ...
# Rule: avocado -> pasta
# Support: 0.02
# Confidence: 0.5
# Lift: 4.166666666666667
# ...
# Rule: avocado -> soup
# Support: 0.04
# Confidence: 0.33333333333333337
# Lift: 4.166666666666667
# ...
# Rule: avocado -> toothpaste
# Support: 0.02
# Confidence: 1.0
# Lift: 8.333333333333334
# ...
